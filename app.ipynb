# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import config
 
options = Options() # 取消彈出視窗
options.add_argument("--disable-notifications")
 
chrome = webdriver.Chrome('./chromedriver', chrome_options=options)
chrome.get("https://www.facebook.com/")

email = chrome.find_element("name", "email")
password =  chrome.find_element("name", "pass")

email.send_keys(config.email)
password.send_keys(config.password)
password.submit()

time.sleep(3)
chrome.get('https://www.facebook.com/groups/1637795373171061')


for x in range(1, 4):
    chrome.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(5)

soup = BeautifulSoup(chrome.page_source, 'html.parser')
titles = soup.find_all('span', {
    'class': 'x193iq5w xeuugli x13faqbe x1vvkbs xlh3980 xvmahel x1n0sxbx x1lliihq x1s928wv xhkezso x1gmr53x x1cpjm7i x1fgarty x1943h6x x4zkp8e x3x7a5m x6prxxf xvq8zen xo1l8bm xzsf02u x1yc453h'})

for title in titles:
    posts = title.find_all('div', dir='auto')
 
    if len(posts):
        for post in posts:
            print(post.getText())
        print("-" * 30)
chrome.quit()
# Out:
# /var/folders/f1/kn2msxf92sg8zy59mtjpml480000gn/T/ipykernel_20852/885454393.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   chrome = webdriver.Chrome('./chromedriver', chrome_options=options)
# /var/folders/f1/kn2msxf92sg8zy59mtjpml480000gn/T/ipykernel_20852/885454393.py:11: DeprecationWarning: use options instead of chrome_options
#   chrome = webdriver.Chrome('./chromedriver', chrome_options=options)
# #代理代管～出租套房
# ［地點］北區北門路二段近火車站成大醫院
# ［類型]全新剛整理好的小套房…… 顯示更多
# ------------------------------
# 東區~府連路休閒風套房出租
# 長榮路一段及府連路口(星巴克附近巷內)
# 租金：6800元/月 (3樓)
# 押金：兩個月
# 電費：一度5元
# 水費：…… 顯示更多
# ------------------------------
# 可申請租金補助
# 符合社會住宅資格另有優惠
# 租金：一般戶 $ 23000
#                    第一類 $19355
#                    第二類 $ 15800…… 顯示更多
# ------------------------------
# 國成社會住宅東區溫馨質感住家
# .
# 地址：台南市東區
# 租金：22,000元（含管理費）
# 坪數：約25坪
# …… 顯示更多
# ------------------------------
# 萬年二街電梯大樓
# 寵物友善
# 可申請補助
# 地址：台南市南區
# 租金：16000
# 車位…… 顯示更多
# ...
